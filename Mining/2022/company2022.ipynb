# %%
import pandas as pd

# %%
df=pd.read_excel("cleaned.xlsx")
df
# Out:
#             company pointer    branch  ce1  ce2  entc1  entc2  it  male  \
# 0      Lowe's India     PPO  All (UG)    0    0      1      0   0     0
# 1       TCS Digital    7.95  All (UG)    1    0      4      1   1     4
# 2           PhonePe     7.5  All (UG)    3    0      0      0   0     3
# 3     Deutsche Bank     PPO  All (UG)    2    0      0      0   1     2
# 4     Deutsche Bank    7.95  All (UG)    6    0      0      0   1     6
# ..              ...     ...       ...  ...  ...    ...    ...  ..   ...
# 113         Sell.do    6.82  All (UG)    0    0      1      0   0     1
# 114        Mindtree    6.82  All (UG)    0    0      1      0   0     1
# 115        Reliance    6.82  All (UG)    0    0      0      0   0     0
# 116    ITC Infotech    6.82  All (UG)    1    0      1      1   0     2
# 117  Productdossier      NC  All (UG)    0    0      1      0   0     1
#
#      female  total  salary       date  investment
# 0         1      1   19.34        PPO       19.34
# ...

# %%
df["date"].unique()
# Out:
# array(['PPO', '23-07-21', '28-07-21', '29-07-21', '31-07-21', '01-08-21',
#        '03-08-21', '04-01-22', '10-08-21', '05-08-21', '06-08-21',
#        '09-08-21', '10-09-21', '14-08-21', '24-08-21', '15-08-21',
#        '19-08-21', '16-08-21', '25-08-21', '27-08-21', '30-08-21',
#        '26-08-21', '01-09-21', '02-09-21', '29-08-21', '08-09-21',
#        '15-09-21', '18-09-21', '13-09-21', '11-09-21', '20-08-21',
#        '16-09-21', '24-09-21', '28-09-21', '04-10-21', '05-10-21',
#        '06-10-21', '20-09-21', '16-10-21', '03-10-21', '18-10-21',
#        '14-10-21', '08-10-21', '07-10-21', '27-10-21', '29-10-21',
#        '25-10-21', '30-10-21', '13-11-21', '18-11-21', '17-11-21',
#        '29-11-21', '08-12-21', '10-12-21', '07-12-21', '17-12-21',
#        '09-11-21', '27-12-21', '10-01-22', '25-01-22', '28-01-22',
#        '31-01-22', '28-02-22', '01-03-22', '14-03-22', '22-03-22',
#        '02-04-22', '18-04-22', '05-05-22', '01-07-22', '06-07-22',
# ...

# %%
df["date"]=pd.to_datetime(df["date"],errors="coerce")
df
# Out:
#             company pointer    branch  ce1  ce2  entc1  entc2  it  male  \
# 0      Lowe's India     PPO  All (UG)    0    0      1      0   0     0
# 1       TCS Digital    7.95  All (UG)    1    0      4      1   1     4
# 2           PhonePe     7.5  All (UG)    3    0      0      0   0     3
# 3     Deutsche Bank     PPO  All (UG)    2    0      0      0   1     2
# 4     Deutsche Bank    7.95  All (UG)    6    0      0      0   1     6
# ..              ...     ...       ...  ...  ...    ...    ...  ..   ...
# 113         Sell.do    6.82  All (UG)    0    0      1      0   0     1
# 114        Mindtree    6.82  All (UG)    0    0      1      0   0     1
# 115        Reliance    6.82  All (UG)    0    0      0      0   0     0
# 116    ITC Infotech    6.82  All (UG)    1    0      1      1   0     2
# 117  Productdossier      NC  All (UG)    0    0      1      0   0     1
#
#      female  total  salary       date  investment
# 0         1      1   19.34        NaT       19.34
# ...

# %%
df=df[df["pointer"]!="PPO"]
df
# Out:
#                  company pointer    branch  ce1  ce2  entc1  entc2  it  male  \
# 1            TCS Digital    7.95  All (UG)    1    0      4      1   1     4
# 2                PhonePe     7.5  All (UG)    3    0      0      0   0     3
# 4          Deutsche Bank    7.95  All (UG)    6    0      0      0   1     6
# 5    Trilogy Innovations      NC  All (UG)    0    0      0      0   1     1
# 6      Espressif Systems       8  All (UG)    5    0      1      0   0     6
# ..                   ...     ...       ...  ...  ...    ...    ...  ..   ...
# 113              Sell.do    6.82  All (UG)    0    0      1      0   0     1
# 114             Mindtree    6.82  All (UG)    0    0      1      0   0     1
# 115             Reliance    6.82  All (UG)    0    0      0      0   0     0
# 116         ITC Infotech    6.82  All (UG)    1    0      1      1   0     2
# 117       Productdossier      NC  All (UG)    0    0      1      0   0     1
#
# ...

# %%
df["ce"]=df["ce1"]+df["ce2"]
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\815695153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ce"]=df["ce1"]+df["ce2"]
#                  company pointer    branch  ce1  ce2  entc1  entc2  it  male  \
# 1            TCS Digital    7.95  All (UG)    1    0      4      1   1     4
# 2                PhonePe     7.5  All (UG)    3    0      0      0   0     3
# 4          Deutsche Bank    7.95  All (UG)    6    0      0      0   1     6
# 5    Trilogy Innovations      NC  All (UG)    0    0      0      0   1     1
# 6      Espressif Systems       8  All (UG)    5    0      1      0   0     6
# ..                   ...     ...       ...  ...  ...    ...    ...  ..   ...
# ...

# %%
df["ce1"]=df["ce"]
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\32361896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ce1"]=df["ce"]
#                  company pointer    branch  ce1  ce2  entc1  entc2  it  male  \
# 1            TCS Digital    7.95  All (UG)    1    0      4      1   1     4
# 2                PhonePe     7.5  All (UG)    3    0      0      0   0     3
# 4          Deutsche Bank    7.95  All (UG)    6    0      0      0   1     6
# 5    Trilogy Innovations      NC  All (UG)    0    0      0      0   1     1
# 6      Espressif Systems       8  All (UG)    5    0      1      0   0     6
# ..                   ...     ...       ...  ...  ...    ...    ...  ..   ...
# ...

# %%
df.drop("ce",axis=1,inplace=True)
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\1474771432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("ce",axis=1,inplace=True)
#                  company pointer    branch  ce1  ce2  entc1  entc2  it  male  \
# 1            TCS Digital    7.95  All (UG)    1    0      4      1   1     4
# 2                PhonePe     7.5  All (UG)    3    0      0      0   0     3
# 4          Deutsche Bank    7.95  All (UG)    6    0      0      0   1     6
# 5    Trilogy Innovations      NC  All (UG)    0    0      0      0   1     1
# 6      Espressif Systems       8  All (UG)    5    0      1      0   0     6
# ..                   ...     ...       ...  ...  ...    ...    ...  ..   ...
# 113              Sell.do    6.82  All (UG)    0    0      1      0   0     1
# ...

# %%
df.drop("ce2",axis=1,inplace=True)
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\1789834067.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("ce2",axis=1,inplace=True)
#                  company pointer    branch  ce1  entc1  entc2  it  male  \
# 1            TCS Digital    7.95  All (UG)    1      4      1   1     4
# 2                PhonePe     7.5  All (UG)    3      0      0   0     3
# 4          Deutsche Bank    7.95  All (UG)    6      0      0   1     6
# 5    Trilogy Innovations      NC  All (UG)    0      0      0   1     1
# 6      Espressif Systems       8  All (UG)    5      1      0   0     6
# ..                   ...     ...       ...  ...    ...    ...  ..   ...
# 113              Sell.do    6.82  All (UG)    0      1      0   0     1
# ...

# %%
df["entc"]=df["entc1"]+df["entc2"]
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\3901842339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["entc"]=df["entc1"]+df["entc2"]
#                  company pointer    branch  ce1  entc1  entc2  it  male  \
# 1            TCS Digital    7.95  All (UG)    1      4      1   1     4
# 2                PhonePe     7.5  All (UG)    3      0      0   0     3
# 4          Deutsche Bank    7.95  All (UG)    6      0      0   1     6
# 5    Trilogy Innovations      NC  All (UG)    0      0      0   1     1
# 6      Espressif Systems       8  All (UG)    5      1      0   0     6
# ..                   ...     ...       ...  ...    ...    ...  ..   ...
# ...

# %%
df["entc1"]=df["entc"]
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\535291748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["entc1"]=df["entc"]
#                  company pointer    branch  ce1  entc1  entc2  it  male  \
# 1            TCS Digital    7.95  All (UG)    1      5      1   1     4
# 2                PhonePe     7.5  All (UG)    3      0      0   0     3
# 4          Deutsche Bank    7.95  All (UG)    6      0      0   1     6
# 5    Trilogy Innovations      NC  All (UG)    0      0      0   1     1
# 6      Espressif Systems       8  All (UG)    5      1      0   0     6
# ..                   ...     ...       ...  ...    ...    ...  ..   ...
# 113              Sell.do    6.82  All (UG)    0      1      0   0     1
# ...

# %%
df.drop("entc2",axis=1,inplace=True)
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\3722831772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("entc2",axis=1,inplace=True)
#                  company pointer    branch  ce1  entc1  it  male  female  \
# 1            TCS Digital    7.95  All (UG)    1      5   1     4       3
# 2                PhonePe     7.5  All (UG)    3      0   0     3       0
# 4          Deutsche Bank    7.95  All (UG)    6      0   1     6       1
# 5    Trilogy Innovations      NC  All (UG)    0      0   1     1       0
# 6      Espressif Systems       8  All (UG)    5      1   0     6       0
# ..                   ...     ...       ...  ...    ...  ..   ...     ...
# 113              Sell.do    6.82  All (UG)    0      1   0     1       0
# ...

# %%
df.drop("entc",axis=1,inplace=True)
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\2073532208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("entc",axis=1,inplace=True)
#                  company pointer    branch  ce1  entc1  it  male  female  \
# 1            TCS Digital    7.95  All (UG)    1      5   1     4       3
# 2                PhonePe     7.5  All (UG)    3      0   0     3       0
# 4          Deutsche Bank    7.95  All (UG)    6      0   1     6       1
# 5    Trilogy Innovations      NC  All (UG)    0      0   1     1       0
# 6      Espressif Systems       8  All (UG)    5      1   0     6       0
# ..                   ...     ...       ...  ...    ...  ..   ...     ...
# 113              Sell.do    6.82  All (UG)    0      1   0     1       0
# ...

# %%
df.dtypes
# Out:
# company               object
# pointer               object
# branch                object
# ce1                    int64
# entc1                  int64
# it                     int64
# male                   int64
# female                 int64
# total                  int64
# salary               float64
# date          datetime64[ns]
# investment           float64
# dtype: object

# %%
df.rename(columns={"ce1":"CE"},inplace=True)
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\2424286093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"ce1":"CE"},inplace=True)
#                  company pointer    branch  CE  entc1  it  male  female  \
# 1            TCS Digital    7.95  All (UG)   1      5   1     4       3
# 2                PhonePe     7.5  All (UG)   3      0   0     3       0
# 4          Deutsche Bank    7.95  All (UG)   6      0   1     6       1
# 5    Trilogy Innovations      NC  All (UG)   0      0   1     1       0
# 6      Espressif Systems       8  All (UG)   5      1   0     6       0
# ..                   ...     ...       ...  ..    ...  ..   ...     ...
# 113              Sell.do    6.82  All (UG)   0      1   0     1       0
# ...

# %%
df.rename(columns={"entc1":"ENTC"},inplace=True)
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\1111007368.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"entc1":"ENTC"},inplace=True)
#                  company pointer    branch  CE  ENTC  it  male  female  total  \
# 1            TCS Digital    7.95  All (UG)   1     5   1     4       3      7
# 2                PhonePe     7.5  All (UG)   3     0   0     3       0      3
# 4          Deutsche Bank    7.95  All (UG)   6     0   1     6       1      7
# 5    Trilogy Innovations      NC  All (UG)   0     0   1     1       0      1
# 6      Espressif Systems       8  All (UG)   5     1   0     6       0      6
# ..                   ...     ...       ...  ..   ...  ..   ...     ...    ...
# ...

# %%
df.rename(columns={"it":"IT"},inplace=True)
df
# Out:
# C:\Users\SHUBHAM SUKUM\AppData\Local\Temp\ipykernel_2428\701429794.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"it":"IT"},inplace=True)
#                  company pointer    branch  CE  ENTC  IT  male  female  total  \
# 1            TCS Digital    7.95  All (UG)   1     5   1     4       3      7
# 2                PhonePe     7.5  All (UG)   3     0   0     3       0      3
# 4          Deutsche Bank    7.95  All (UG)   6     0   1     6       1      7
# 5    Trilogy Innovations      NC  All (UG)   0     0   1     1       0      1
# 6      Espressif Systems       8  All (UG)   5     1   0     6       0      6
# ..                   ...     ...       ...  ..   ...  ..   ...     ...    ...
# ...

# %%
df["branch"].unique()
# Out:
# array(['All (UG)', 'CS & IT (UG)', 'E&TC (UG)'], dtype=object)

# %%
df.to_excel("company2022.xlsx",index=False)

# %%
json_data=df.to_json(orient="records")
json_data
# Out:
# '[{"company":"TCS Digital","pointer":"7.95","branch":"All (UG)","CE":1,"ENTC":5,"IT":1,"male":4,"female":3,"total":7,"salary":7.01,"date":1626998400000,"investment":49.07},{"company":"PhonePe","pointer":"7.5","branch":"All (UG)","CE":3,"ENTC":0,"IT":0,"male":3,"female":0,"total":3,"salary":30.5,"date":1627430400000,"investment":91.5},{"company":"Deutsche Bank","pointer":"7.95","branch":"All (UG)","CE":6,"ENTC":0,"IT":1,"male":6,"female":1,"total":7,"salary":19.63,"date":1627516800000,"investment":137.41},{"company":"Trilogy Innovations","pointer":"NC","branch":"All (UG)","CE":0,"ENTC":0,"IT":1,"male":1,"female":0,"total":1,"salary":36.5,"date":1627516800000,"investment":36.5},{"company":"Espressif Systems","pointer":"8","branch":"All (UG)","CE":5,"ENTC":1,"IT":0,"male":6,"female":0,"total":6,"salary":18.9,"date":1627689600000,"investment":113.4},{"company":"Bajaj Finance","pointer":"NC","branch":"All (UG)","CE":40,"ENTC":20,"IT":23,"male":68,"female":15,"total":83,"salary":12.0,"date
# ...

# %%
with open("2022.json","w") as file:
    file.write(json_data)

# %%
ppo=pd.read_excel("PPO.xlsx")
ppo
# Out:
#             company pointer        branch  ce1  ce2  entc1  entc2  it  male  \
# 0      Lowe's India     PPO      All (UG)    0    0      1      0   0     0
# 1     Deutsche Bank     PPO      All (UG)    2    0      0      0   1     2
# 2     Credit Suisse     PPO  CS & IT (UG)    1    1      0      0   3     3
# 3          RBL Bank     PPO  CS & IT (UG)    1    0      0      0   0     0
# 4     ZS Associates     PPO      All (UG)    0    0      1      0   0     1
# 5               UBS     PPO      All (UG)    2    1      0      0   0     3
# 6      Schlumberger     PPO      All (UG)    0    2      1      1   1     0
# 7   Arista Networks     PPO      All (UG)    0    0      0      0   0     0
# 8             Adobe     PPO      All (UG)    1    0      0      0   0     0
# 9         Microsoft     PPO      All (UG)    1    0      0      0   1     0
# 10           Amazon     PPO      All (UG)    1    0      0      0   0     1
#
#     female  total  salary  date  investment
# ...

# %%
ppo.drop("pointer",axis=1,inplace=True)
ppo
# Out:
#             company        branch  ce1  ce2  entc1  entc2  it  male  female  \
# 0      Lowe's India      All (UG)    0    0      1      0   0     0       1
# 1     Deutsche Bank      All (UG)    2    0      0      0   1     2       1
# 2     Credit Suisse  CS & IT (UG)    1    1      0      0   3     3       2
# 3          RBL Bank  CS & IT (UG)    1    0      0      0   0     0       1
# 4     ZS Associates      All (UG)    0    0      1      0   0     1       0
# 5               UBS      All (UG)    2    1      0      0   0     3       0
# 6      Schlumberger      All (UG)    0    2      1      1   1     0       5
# 7   Arista Networks      All (UG)    0    0      0      0   0     0       0
# 8             Adobe      All (UG)    1    0      0      0   0     0       1
# 9         Microsoft      All (UG)    1    0      0      0   1     0       2
# 10           Amazon      All (UG)    1    0      0      0   0     1       0
#
#     total  salary  date  investment
# ...

# %%
ppo.drop("date",axis=1,inplace=True)
ppo
# Out:
#             company        branch  ce1  ce2  entc1  entc2  it  male  female  \
# 0      Lowe's India      All (UG)    0    0      1      0   0     0       1
# 1     Deutsche Bank      All (UG)    2    0      0      0   1     2       1
# 2     Credit Suisse  CS & IT (UG)    1    1      0      0   3     3       2
# 3          RBL Bank  CS & IT (UG)    1    0      0      0   0     0       1
# 4     ZS Associates      All (UG)    0    0      1      0   0     1       0
# 5               UBS      All (UG)    2    1      0      0   0     3       0
# 6      Schlumberger      All (UG)    0    2      1      1   1     0       5
# 7   Arista Networks      All (UG)    0    0      0      0   0     0       0
# 8             Adobe      All (UG)    1    0      0      0   0     0       1
# 9         Microsoft      All (UG)    1    0      0      0   1     0       2
# 10           Amazon      All (UG)    1    0      0      0   0     1       0
#
#     total  salary  investment
# ...

# %%
ppo["ce"]=ppo["ce1"]+ppo["ce2"]
ppo
# Out:
#             company        branch  ce1  ce2  entc1  entc2  it  male  female  \
# 0      Lowe's India      All (UG)    0    0      1      0   0     0       1
# 1     Deutsche Bank      All (UG)    2    0      0      0   1     2       1
# 2     Credit Suisse  CS & IT (UG)    1    1      0      0   3     3       2
# 3          RBL Bank  CS & IT (UG)    1    0      0      0   0     0       1
# 4     ZS Associates      All (UG)    0    0      1      0   0     1       0
# 5               UBS      All (UG)    2    1      0      0   0     3       0
# 6      Schlumberger      All (UG)    0    2      1      1   1     0       5
# 7   Arista Networks      All (UG)    0    0      0      0   0     0       0
# 8             Adobe      All (UG)    1    0      0      0   0     0       1
# 9         Microsoft      All (UG)    1    0      0      0   1     0       2
# 10           Amazon      All (UG)    1    0      0      0   0     1       0
#
#     total  salary  investment  ce
# ...

# %%
ppo["entc"]=ppo["entc1"]+ppo["entc2"]
ppo
# Out:
#             company        branch  ce1  ce2  entc1  entc2  it  male  female  \
# 0      Lowe's India      All (UG)    0    0      1      0   0     0       1
# 1     Deutsche Bank      All (UG)    2    0      0      0   1     2       1
# 2     Credit Suisse  CS & IT (UG)    1    1      0      0   3     3       2
# 3          RBL Bank  CS & IT (UG)    1    0      0      0   0     0       1
# 4     ZS Associates      All (UG)    0    0      1      0   0     1       0
# 5               UBS      All (UG)    2    1      0      0   0     3       0
# 6      Schlumberger      All (UG)    0    2      1      1   1     0       5
# 7   Arista Networks      All (UG)    0    0      0      0   0     0       0
# 8             Adobe      All (UG)    1    0      0      0   0     0       1
# 9         Microsoft      All (UG)    1    0      0      0   1     0       2
# 10           Amazon      All (UG)    1    0      0      0   0     1       0
#
#     total  salary  investment  ce  entc
# ...

# %%
ppo["ce1"]=ppo["ce"]
ppo["ce2"]=ppo["entc"]
ppo
# Out:
#             company        branch  ce1  ce2  entc1  entc2  it  male  female  \
# 0      Lowe's India      All (UG)    0    1      1      0   0     0       1
# 1     Deutsche Bank      All (UG)    2    0      0      0   1     2       1
# 2     Credit Suisse  CS & IT (UG)    2    0      0      0   3     3       2
# 3          RBL Bank  CS & IT (UG)    1    0      0      0   0     0       1
# 4     ZS Associates      All (UG)    0    1      1      0   0     1       0
# 5               UBS      All (UG)    3    0      0      0   0     3       0
# 6      Schlumberger      All (UG)    2    2      1      1   1     0       5
# 7   Arista Networks      All (UG)    0    0      0      0   0     0       0
# 8             Adobe      All (UG)    1    0      0      0   0     0       1
# 9         Microsoft      All (UG)    1    0      0      0   1     0       2
# 10           Amazon      All (UG)    1    0      0      0   0     1       0
#
#     total  salary  investment  ce  entc
# ...

# %%
ppo.drop("ce",axis=1,inplace=True)
ppo
# Out:
#             company        branch  ce1  ce2  entc1  entc2  it  male  female  \
# 0      Lowe's India      All (UG)    0    1      1      0   0     0       1
# 1     Deutsche Bank      All (UG)    2    0      0      0   1     2       1
# 2     Credit Suisse  CS & IT (UG)    2    0      0      0   3     3       2
# 3          RBL Bank  CS & IT (UG)    1    0      0      0   0     0       1
# 4     ZS Associates      All (UG)    0    1      1      0   0     1       0
# 5               UBS      All (UG)    3    0      0      0   0     3       0
# 6      Schlumberger      All (UG)    2    2      1      1   1     0       5
# 7   Arista Networks      All (UG)    0    0      0      0   0     0       0
# 8             Adobe      All (UG)    1    0      0      0   0     0       1
# 9         Microsoft      All (UG)    1    0      0      0   1     0       2
# 10           Amazon      All (UG)    1    0      0      0   0     1       0
#
#     total  salary  investment  entc
# ...

# %%
ppo.drop("entc1",axis=1,inplace=True)
ppo.drop("entc2",axis=1,inplace=True)
ppo.drop("entc",axis=1,inplace=True)
ppo
# Out:
#             company        branch  ce1  ce2  it  male  female  total  salary  \
# 0      Lowe's India      All (UG)    0    1   0     0       1      1   19.34
# 1     Deutsche Bank      All (UG)    2    0   1     2       1      3   19.63
# 2     Credit Suisse  CS & IT (UG)    2    0   3     3       2      5   13.59
# 3          RBL Bank  CS & IT (UG)    1    0   0     0       1      1    9.00
# 4     ZS Associates      All (UG)    0    1   0     1       0      1   12.50
# 5               UBS      All (UG)    3    0   0     3       0      3   10.00
# 6      Schlumberger      All (UG)    2    2   1     0       5      5    9.58
# 7   Arista Networks      All (UG)    0    0   0     0       0      0   21.50
# 8             Adobe      All (UG)    1    0   0     0       1      1   40.92
# 9         Microsoft      All (UG)    1    0   1     0       2      2   44.70
# 10           Amazon      All (UG)    1    0   0     1       0      1  112.00
#
#     investment
# 0        19.34
# ...

# %%
ppo.rename(columns={"ce1":"CE"},inplace=True)
ppo
# Out:
#             company        branch  CE  ce2  it  male  female  total  salary  \
# 0      Lowe's India      All (UG)   0    1   0     0       1      1   19.34
# 1     Deutsche Bank      All (UG)   2    0   1     2       1      3   19.63
# 2     Credit Suisse  CS & IT (UG)   2    0   3     3       2      5   13.59
# 3          RBL Bank  CS & IT (UG)   1    0   0     0       1      1    9.00
# 4     ZS Associates      All (UG)   0    1   0     1       0      1   12.50
# 5               UBS      All (UG)   3    0   0     3       0      3   10.00
# 6      Schlumberger      All (UG)   2    2   1     0       5      5    9.58
# 7   Arista Networks      All (UG)   0    0   0     0       0      0   21.50
# 8             Adobe      All (UG)   1    0   0     0       1      1   40.92
# 9         Microsoft      All (UG)   1    0   1     0       2      2   44.70
# 10           Amazon      All (UG)   1    0   0     1       0      1  112.00
#
#     investment
# 0        19.34
# 1        58.89
# ...

# %%
ppo.rename(columns={"it":"IT"},inplace=True)
ppo.rename(columns={"ce2":"ENTC"},inplace=True)
ppo
# Out:
#             company        branch  CE  ENTC  IT  male  female  total  salary  \
# 0      Lowe's India      All (UG)   0     1   0     0       1      1   19.34
# 1     Deutsche Bank      All (UG)   2     0   1     2       1      3   19.63
# 2     Credit Suisse  CS & IT (UG)   2     0   3     3       2      5   13.59
# 3          RBL Bank  CS & IT (UG)   1     0   0     0       1      1    9.00
# 4     ZS Associates      All (UG)   0     1   0     1       0      1   12.50
# 5               UBS      All (UG)   3     0   0     3       0      3   10.00
# 6      Schlumberger      All (UG)   2     2   1     0       5      5    9.58
# 7   Arista Networks      All (UG)   0     0   0     0       0      0   21.50
# 8             Adobe      All (UG)   1     0   0     0       1      1   40.92
# 9         Microsoft      All (UG)   1     0   1     0       2      2   44.70
# 10           Amazon      All (UG)   1     0   0     1       0      1  112.00
#
#     investment
# 0        19.34
# ...

# %%
j_data=ppo.to_json(orient="records")
j_data
# Out:
# '[{"company":"Lowe\'s India","branch":"All (UG)","CE":0,"ENTC":1,"IT":0,"male":0,"female":1,"total":1,"salary":19.34,"investment":19.34},{"company":"Deutsche Bank","branch":"All (UG)","CE":2,"ENTC":0,"IT":1,"male":2,"female":1,"total":3,"salary":19.63,"investment":58.89},{"company":"Credit Suisse","branch":"CS & IT (UG)","CE":2,"ENTC":0,"IT":3,"male":3,"female":2,"total":5,"salary":13.59,"investment":67.95},{"company":"RBL Bank","branch":"CS & IT (UG)","CE":1,"ENTC":0,"IT":0,"male":0,"female":1,"total":1,"salary":9.0,"investment":9.0},{"company":"ZS Associates","branch":"All (UG)","CE":0,"ENTC":1,"IT":0,"male":1,"female":0,"total":1,"salary":12.5,"investment":12.5},{"company":"UBS","branch":"All (UG)","CE":3,"ENTC":0,"IT":0,"male":3,"female":0,"total":3,"salary":10.0,"investment":30.0},{"company":"Schlumberger","branch":"All (UG)","CE":2,"ENTC":2,"IT":1,"male":0,"female":5,"total":5,"salary":9.58,"investment":47.9},{"company":"Arista Networks","branch":"All (UG)","CE":0,"ENTC":0,"IT"
# ...

# %%
with open("ppo2022.json","w") as j_file:
    j_file.write(j_data)
