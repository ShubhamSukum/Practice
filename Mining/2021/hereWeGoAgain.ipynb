# %%
import pandas as pd

# %%
df=pd.read_excel("seperationRemainsPage2.xlsx")
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  12  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0   0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2   2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3   3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0   0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0   0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...  ..
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0   0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0   0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0   0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1   1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0   0
#
#          13        14    15  ce  entc  it
# ...

# %%
df.drop("ce",axis=1,inplace=True)
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  12  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0   0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2   2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3   3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0   0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0   0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...  ..
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0   0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0   0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0   0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1   1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0   0
#
#          13        14    15  entc  it
# ...

# %%
df.drop("entc",inplace=True,axis=1)
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  12  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0   0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2   2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3   3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0   0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0   0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...  ..
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0   0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0   0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0   0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1   1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0   0
#
#          13        14    15  it
# ...

# %%
df.drop("it",axis=1,inplace=True)
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  12  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0   0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2   2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3   3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0   0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0   0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...  ..
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0   0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0   0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0   0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1   1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0   0
#
#          13        14    15
# ...

# %%
df.columns.values[11]="investment"
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  12  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0   0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2   2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3   3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0   0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0   0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...  ..
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0   0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0   0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0   0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1   1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0   0
#
#          13        14  investment
# ...

# %%
df.columns.values[10]="date"
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  12  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0   0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2   2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3   3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0   0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0   0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...  ..
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0   0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0   0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0   0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1   1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0   0
#
#          13      date  investment
# ...

# %%
df.columns=["company","pointer","branch","CE","ENTC","IT","male","female","total","salary","date","investment"]
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0
#
#     total   salary      date  investment
# 0       0  1 10.00  21/04/21        10.0
# ...

# %%
df["date"]=pd.to_datetime(df["date"],errors="coerce")
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0
#
#     total   salary       date  investment
# 0       0  1 10.00 2021-04-21        10.0
# ...

# %%
temp=df

# %%
temp[['numeric_salary', 'decimal_salary']] = temp['salary'].str.split(' ', expand=True)

# %%
temp
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0
#
#     total   salary       date  investment numeric_salary decimal_salary
# ...

# %%
df["total"]=df["numeric_salary"]
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0
#
#    total   salary       date  investment numeric_salary decimal_salary
# ...

# %%
df["salary"]=df["decimal_salary"]
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0
#
#    total salary       date  investment numeric_salary decimal_salary
# ...

# %%
df.drop("numeric_salary",axis=1,inplace=True)
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0
#
#    total salary       date  investment decimal_salary
# ...

# %%
df.drop("decimal_salary",axis=1,inplace=True)
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0
#
#    total salary       date  investment
# 0      1  10.00 2021-04-21        10.0
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# company               object
# pointer               object
# branch                object
# CE                     int64
# ENTC                   int64
# IT                     int64
# male                   int64
# female                 int64
# total                 object
# salary                object
# date          datetime64[ns]
# investment           float64
# dtype: object

# %%
df["total"]=df["total"].astype(int)
df.dtypes
# Out:
# company               object
# pointer               object
# branch                object
# CE                     int64
# ENTC                   int64
# IT                     int64
# male                   int64
# female                 int64
# total                  int32
# salary                object
# date          datetime64[ns]
# investment           float64
# dtype: object

# %%
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0
#
#     total salary       date  investment
# 0       1  10.00 2021-04-21        10.0
# ...

# %%
df.to_excel("page2done.xlsx",index=False)

# %%
json_data=df.to_json(orient="records")
json_data
# Out:
# '[{"company":"Jombay","pointer":"NC","branch":"CE & IT (UG)","CE":1,"ENTC":0,"IT":0,"male":1,"female":0,"total":1,"salary":"10.00","date":1618963200000,"investment":10.0},{"company":"PTC Software","pointer":"NC","branch":"All (UG)","CE":1,"ENTC":1,"IT":1,"male":1,"female":2,"total":3,"salary":"6.00","date":1619049600000,"investment":18.0},{"company":"Screen Magic","pointer":"6.82","branch":"CE & IT (UG)","CE":2,"ENTC":0,"IT":2,"male":1,"female":3,"total":4,"salary":"7.30","date":1619136000000,"investment":29.2},{"company":"3EA","pointer":"6.82","branch":"All (UG)","CE":0,"ENTC":1,"IT":0,"male":1,"female":0,"total":1,"salary":"6.00","date":1612483200000,"investment":6.0},{"company":"EnthrallTech","pointer":"6.82","branch":"All (UG)","CE":3,"ENTC":0,"IT":0,"male":3,"female":0,"total":3,"salary":"7.00","date":1614902400000,"investment":21.0},{"company":"Mindstix Software Labs","pointer":"NC","branch":"All (UG)","CE":1,"ENTC":0,"IT":1,"male":1,"female":1,"total":2,"salary":"6.30","date":
# ...

# %%
with open("2021page2.json","w") as json_file:
    json_file.write(json_data)

# %%
df["salary"]=df["salary"].astype('float64')
df.dtypes
# Out:
# company               object
# pointer               object
# branch                object
# CE                     int64
# ENTC                   int64
# IT                     int64
# male                   int64
# female                 int64
# total                  int32
# salary               float64
# date          datetime64[ns]
# investment           float64
# dtype: object

# %%
df
# Out:
#                company pointer        branch  CE  ENTC  IT  male  female  \
# 0               Jombay      NC  CE & IT (UG)   1     0   0     1       0
# 1         PTC Software      NC      All (UG)   1     1   1     1       2
# 2         Screen Magic    6.82  CE & IT (UG)   2     0   2     1       3
# 3                  3EA    6.82      All (UG)   0     1   0     1       0
# 4         EnthrallTech    6.82      All (UG)   3     0   0     3       0
# ..                 ...     ...           ...  ..   ...  ..   ...     ...
# 56  Aligned Automation    6.82      All (UG)   0     2   0     2       0
# 57       IGT Solutions    7.38  CE & IT (UG)   0     0   0     0       0
# 58              Zocdoc    6.82      All (UG)   0     1   0     1       0
# 59          iQ Digital    6.82      All (UG)   0     0   1     0       1
# 60        JISA Softech      NC      All (UG)   0     1   0     1       0
#
#     total  salary       date  investment
# 0       1   10.00 2021-04-21        10.0
# ...

# %%
df.to_excel("page2done.xlsx",index=False)

# %%
json_data=df.to_json(orient="records")
json_data
# Out:
# '[{"company":"Jombay","pointer":"NC","branch":"CE & IT (UG)","CE":1,"ENTC":0,"IT":0,"male":1,"female":0,"total":1,"salary":10.0,"date":1618963200000,"investment":10.0},{"company":"PTC Software","pointer":"NC","branch":"All (UG)","CE":1,"ENTC":1,"IT":1,"male":1,"female":2,"total":3,"salary":6.0,"date":1619049600000,"investment":18.0},{"company":"Screen Magic","pointer":"6.82","branch":"CE & IT (UG)","CE":2,"ENTC":0,"IT":2,"male":1,"female":3,"total":4,"salary":7.3,"date":1619136000000,"investment":29.2},{"company":"3EA","pointer":"6.82","branch":"All (UG)","CE":0,"ENTC":1,"IT":0,"male":1,"female":0,"total":1,"salary":6.0,"date":1612483200000,"investment":6.0},{"company":"EnthrallTech","pointer":"6.82","branch":"All (UG)","CE":3,"ENTC":0,"IT":0,"male":3,"female":0,"total":3,"salary":7.0,"date":1614902400000,"investment":21.0},{"company":"Mindstix Software Labs","pointer":"NC","branch":"All (UG)","CE":1,"ENTC":0,"IT":1,"male":1,"female":1,"total":2,"salary":6.3,"date":1620172800000,"inv
# ...

# %%
with open("2021page2.json","w") as json_file:
    json_file.write(json_data)
