# %%
import tabula
import pandas as pd

# %%
file_path="2020-1-2.pdf"

# %%
tables=tabula.read_pdf(file_path,pages="all",multiple_tables=True)

# %%
excelWriter=pd.ExcelWriter("twoPages21.xlsx")

# %%
for i,table in enumerate(tables):
    table.to_excel(excelWriter,sheet_name=f'Table_{i+1}',index=False)

# %%
excelWriter.save()

# %% [markdown]
# ## Excel to Jupyter Notebook

# %%
df=pd.read_excel("twoPages21.xlsx",header=None)
df
# Out:
#                                                    0                    1   \
# 0   Society for Computer Technology and Research’s...           Unnamed: 0
# 1                   Students Placement (Company Wise)                  NaN
# 2                                             Sr. No.              Company
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# ..                                                ...                  ...
# 87                                                 72         Altizon Inc.
# 88                                                 73             Uolo.com
# 89                                                 74  K12 Techno Services
# 90                                                 75          PlanetSpark
# 91                                                 76           TechVerito
#
#                             2                3           4           5   \
# 0                   Unnamed: 1       Unnamed: 2  Unnamed: 3  Unnamed: 4
# 1                          NaN              NaN         NaN         NaN
# 2   Criteria (CGPA & Branches)               UG          PG       Total
# 3                          NaN              NaN       BE CE     BE E&TC
# 4                          NaN              NaN     Shift 1     Shift 2
# ..                         ...              ...         ...         ...
# 87                        7.00         All (UG)           1           1
# 88                        6.82     CE & IT (UG)           0           0
# 89                          NC  All (UG and PG)           0           0
# 90                          NC         All (UG)           0           0
# 91                        7.38     CE & IT (UG)           0           0
#
#             6           7                  8           9           10  \
# 0   Unnamed: 5  Unnamed: 6         Unnamed: 7  Unnamed: 8  Unnamed: 9
# 1          NaN         NaN                NaN         NaN         NaN
# 2     Sal. LPA  Visit Date  Total Salary\rLPA         NaN         NaN
# 3       BE  IT      ME  CE           ME\rE&TC      ME  IT         NaN
# 4      Shift 1     Shift 2                  M           F           T
# ..         ...         ...                ...         ...         ...
# 87           0           0                  1         NaN         NaN
# 88         NaN         NaN                  0         NaN         NaN
# 89           5           0                  1           1           0
# 90           1           1                  1         NaN         NaN
# 91         NaN         NaN                  0         NaN         NaN
#
#              11           12           13           14           15  \
# 0   Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# ..          ...          ...          ...          ...          ...
# 87          NaN            2            1            3         8.25
# 88          NaN            0            0            0           12
# 89            0            5            2            7            6
# 90          NaN            2            1            3          6.5
# 91          NaN            0            0            0            6
#
#              16           17
# 0   Unnamed: 15  Unnamed: 16
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# ..          ...          ...
# 87     19/03/21        24.75
# 88     22/03/21            0
# 89     23/03/21           42
# 90     07/04/21         19.5
# 91     13/04/21            0
#
# [92 rows x 18 columns]
